# %% [markdown]
# **AI ML SMARTBRIDGE - GOOGLE EXTERNSHIP 2023**\
# **NINAD NILESH SUGANDHI**\
# **ASSIGNMENT 3 - PENGUIN CLASSIFICATION ANALYSIS**

# %% [markdown]
# 1. [Problem Statement](#problem-statement)
# 2. [Importing Libraries](#importing-libraries)
# 3. [Loading Data](#loading-data) 💎
# 4. [Data Preprocessing and understanding](#data-preprocessing)
# 3. [Data Visualization](#data-visualization) ⚙️\
#     3.1. [Univariate Analysis](#univariate)\
#     3.2. [Bi- Variate Analysis](#bivariate)\
#     3.3. [Multi-Variate Analysis](#multivariate)
# 4. [Descriptive Statistics](#descriptive-statistics) 📊
# 5. [Checking Missing values](#checking-missing)
# 6. [Finding outliers and replacing them](#finding-outliers)
# 7. [Checking correlation of independent variables with target](#checking-correlation)
# 8. [Checking for categorical columns and performing encoding](#encoding)
# 9. [Splitting data into dependent and independent variables](#splitting-dependent)
# 9. [Scaling the data](#scaling)
# 10. [Splitting the data into training and testing](#splitting)
# 11. [Checking the training and testing data shape](#checking-shape)

# %% [markdown]
# <a id="problem-statement"></a>
# **Problem Statement**

# %% [markdown]
# ![Alt text](image.png)

# %% [markdown]
# ![Alt text](image-2.png)

# %% [markdown]
# ![Alt text](image-1.png)

# %% [markdown]
# <a id="importing-libraries"></a>
# **Importing necessary libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
import matplotlib
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import warnings

# %%
warnings.filterwarnings('ignore')           #ignoring warnings

# %% [markdown]
# **Task 1 - Downloading Dataset** from "https://drive.google.com/file/d/1AvRp8hOK-O76WIFvPj_rk10fAZbt8nWH/view?usp=sharing"\
# Penguin Classification Analysis

# %% [markdown]
# <a id="loading-data"></a>
# **Task 2 - Loading and displaying data**

# %%
data = pd.read_csv("D:\\NINAD SUGANDHI\\SMARTBRIDGE\\penguins_size.csv")
data
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 3            NaN     NaN
# 4         3450.0  FEMALE
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [344 rows x 7 columns]

# %%
data.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
data.head(10)
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
# 5  Adelie  Torgersen              39.3             20.6              190.0
# 6  Adelie  Torgersen              38.9             17.8              181.0
# 7  Adelie  Torgersen              39.2             19.6              195.0
# 8  Adelie  Torgersen              34.1             18.1              193.0
# 9  Adelie  Torgersen              42.0             20.2              190.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE
# 5       3650.0    MALE
# 6       3625.0  FEMALE
# 7       4675.0    MALE
# 8       3475.0     NaN
# 9       4250.0     NaN

# %%
data.tail()
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 339  Gentoo  Biscoe               NaN              NaN                NaN
# 340  Gentoo  Biscoe              46.8             14.3              215.0
# 341  Gentoo  Biscoe              50.4             15.7              222.0
# 342  Gentoo  Biscoe              45.2             14.8              212.0
# 343  Gentoo  Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE

# %%
data.tail(10)
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 334  Gentoo  Biscoe              46.2             14.1              217.0
# 335  Gentoo  Biscoe              55.1             16.0              230.0
# 336  Gentoo  Biscoe              44.5             15.7              217.0
# 337  Gentoo  Biscoe              48.8             16.2              222.0
# 338  Gentoo  Biscoe              47.2             13.7              214.0
# 339  Gentoo  Biscoe               NaN              NaN                NaN
# 340  Gentoo  Biscoe              46.8             14.3              215.0
# 341  Gentoo  Biscoe              50.4             15.7              222.0
# 342  Gentoo  Biscoe              45.2             14.8              212.0
# 343  Gentoo  Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 334       4375.0  FEMALE
# 335       5850.0    MALE
# 336       4875.0       .
# 337       6000.0    MALE
# 338       4925.0  FEMALE
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE

# %% [markdown]
# <a id="data-preprocessing"></a>
# **Data Preprocessing and understanding**

# %%
data.shape
# Out:
# (344, 7)

# %%
data.size
# Out:
# 2408

# %%
data.isnull()
# Out:
#      species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0      False   False             False            False              False
# 1      False   False             False            False              False
# 2      False   False             False            False              False
# 3      False   False              True             True               True
# 4      False   False             False            False              False
# ..       ...     ...               ...              ...                ...
# 339    False   False              True             True               True
# 340    False   False             False            False              False
# 341    False   False             False            False              False
# 342    False   False             False            False              False
# 343    False   False             False            False              False
#
#      body_mass_g    sex
# 0          False  False
# 1          False  False
# 2          False  False
# 3           True   True
# 4          False  False
# ..           ...    ...
# 339         True   True
# 340        False  False
# 341        False  False
# 342        False  False
# 343        False  False
#
# [344 rows x 7 columns]

# %%
data.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
data.info
# Out:
# <bound method DataFrame.info of     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 3            NaN     NaN
# 4         3450.0  FEMALE
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [344 rows x 7 columns]>

# %%
data.describe
# Out:
# <bound method NDFrame.describe of     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 3            NaN     NaN
# 4         3450.0  FEMALE
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [344 rows x 7 columns]>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
data.dtypes
# Out:
# species               object
# island                object
# culmen_length_mm     float64
# culmen_depth_mm      float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
data.duplicated
# Out:
# <bound method DataFrame.duplicated of     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 3            NaN     NaN
# 4         3450.0  FEMALE
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [344 rows x 7 columns]>

# %%
data.empty
# Out:
# False

# %%
data.index
# Out:
# RangeIndex(start=0, stop=344, step=1)

# %%
data.columns
# Out:
# Index(['species', 'island', 'culmen_length_mm', 'culmen_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %% [markdown]
# <a id="data-visualization"></a>
# **Task 3 - Performing Visualizations**

# %% [markdown]
# <a id="univariate"></a>
# **Univariate Visualizations**

# %%
data.culmen_length_mm.plot()
# Out:
# <Axes: >

# %%
data.culmen_depth_mm.plot()
# Out:
# <Axes: >

# %%
data.flipper_length_mm.plot()
# Out:
# <Axes: >

# %%
data.body_mass_g.plot()
# Out:
# <Axes: >

# %%
sns.distplot(data.culmen_length_mm)
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='Density'>

# %%
sns.distplot(data.culmen_depth_mm)
# Out:
# <Axes: xlabel='culmen_depth_mm', ylabel='Density'>

# %%
sns.distplot(data.flipper_length_mm)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.distplot(data.body_mass_g)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
sns.histplot(data=data, x='flipper_length_mm', bins=20, kde=True)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=data, x='culmen_length_mm', bins=20, kde=True)
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='Count'>

# %%
sns.histplot(data=data, x='culmen_depth_mm', bins=20, kde=True)
# Out:
# <Axes: xlabel='culmen_depth_mm', ylabel='Count'>

# %%
sns.histplot(data=data, x='body_mass_g', bins=20, kde=True)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
colors = ['#ff9999','#66b3ff','#99ff99']
explode = (0.05,0.05,0.05)

fig1, ax1 = plt.subplots()

species_counts = data['species'].value_counts()

plt.pie(species_counts, colors = colors, labels=species_counts.index, autopct='%1.1f%%', startangle=90, pctdistance=0.85, explode = explode)
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
sns.pairplot(data)

# %% [markdown]
# <a id="bivariate"></a>
# **Bivariate Analysis**

# %%
plt.figure(figsize=(8, 8))
sns.boxplot(data=data, x='species', y='culmen_length_mm')
plt.title('Box Plot of Culmen Length by Species')
plt.xlabel('Species')
plt.ylabel('Culmen Length (mm)')
plt.show()

# %%
plt.figure(figsize=(8, 8))
sns.scatterplot(data=data, x='culmen_length_mm', y='culmen_depth_mm', hue='species')
plt.title('Scatter Plot of Culmen Length vs. Culmen Depth by Species')
plt.xlabel('Culmen Length (mm)')
plt.ylabel('Culmen Depth (mm)')
plt.show()

# %%
sns.pairplot(data, hue='species', markers=["o", "s", "D"], diag_kind='kde')
plt.suptitle('Pair Plot of Penguin Features by Species')
plt.show()

# %% [markdown]
# <a id="multivariate"></a>
# **Multivariate**

# %%
correlation_matrix = data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='plasma', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=data, x='species', y='flipper_length_mm', hue='sex')
plt.title('Violin Plot of Flipper Length by Species and Sex')
plt.xlabel('Species')
plt.ylabel('Flipper Length (mm)')
plt.show()

# %%
sns.FacetGrid(data, hue="species", height=6) \
   .map(sns.kdeplot, "flipper_length_mm", shade=True) \
   .add_legend()

# %% [markdown]
# <a id="descriptive-statistics"></a>
# **Task 4 - Performing descriptive statistics on the dataset**

# %%
description = data.describe().T.style.background_gradient(
    cmap='viridis',  # colormap
    low=0, high=1,   # range of colors for the gradient
    axis=None        # gradient across the entire DataFrame
)

# styling attributes
styled_description = description.set_properties(**{'font-size': '10pt', 'text-align': 'center'}).bar(subset=['mean'], color='#FFA07A')

styled_description
# Out:
# <style type="text/css">
# #T_4f4c8_row0_col0, #T_4f4c8_row1_col0, #T_4f4c8_row2_col0, #T_4f4c8_row3_col0 {
#   background-color: #460a5d;
#   color: #f1f1f1;
#   font-size: 10pt;
#   text-align: center;
# }
# #T_4f4c8_row0_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
#   font-size: 10pt;
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #FFA07A 1.0%, transparent 1.0%);
# }
# #T_4f4c8_row0_col2, #T_4f4c8_row0_col3, #T_4f4c8_row0_col4, #T_4f4c8_row0_col5, #T_4f4c8_row0_col6, #T_4f4c8_row1_col2, #T_4f4c8_row1_col3, #T_4f4c8_row1_col4, #T_4f4c8_row1_col5, #T_4f4c8_row1_col6, #T_4f4c8_row1_col7, #T_4f4c8_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
#   font-size: 10pt;
#   text-align: center;
# }
# #T_4f4c8_row0_col7 {
#   background-color: #440256;
#   color: #f1f1f1;
#   font-size: 10pt;
#   text-align: center;
# }
# #T_4f4c8_row1_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
#   font-size: 10pt;
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #FFA07A 0.4%, transparent 0.4%);
# }
# #T_4f4c8_row2_col1 {
#   background-color: #46075a;
#   color: #f1f1f1;
#   font-size: 10pt;
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #FFA07A 4.8%, transparent 4.8%);
# }
# #T_4f4c8_row2_col3, #T_4f4c8_row2_col4, #T_4f4c8_row2_col5 {
#   background-color: #450559;
#   color: #f1f1f1;
#   font-size: 10pt;
#   text-align: center;
# }
# #T_4f4c8_row2_col6, #T_4f4c8_row2_col7 {
#   background-color: #46075a;
#   color: #f1f1f1;
#   font-size: 10pt;
#   text-align: center;
# }
# #T_4f4c8_row3_col1 {
#   background-color: #31688e;
#   color: #f1f1f1;
#   font-size: 10pt;
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #FFA07A 100.0%, transparent 100.0%);
# }
# #T_4f4c8_row3_col2 {
#   background-color: #48186a;
#   color: #f1f1f1;
#   font-size: 10pt;
#   text-align: center;
# }
# #T_4f4c8_row3_col3 {
#   background-color: #3f4788;
#   color: #f1f1f1;
#   font-size: 10pt;
#   text-align: center;
# }
# #T_4f4c8_row3_col4 {
#   background-color: #375b8d;
#   color: #f1f1f1;
#   font-size: 10pt;
#   text-align: center;
# }
# #T_4f4c8_row3_col5 {
#   background-color: #32658e;
#   color: #f1f1f1;
#   font-size: 10pt;
#   text-align: center;
# }
# #T_4f4c8_row3_col6 {
#   background-color: #2c728e;
#   color: #f1f1f1;
#   font-size: 10pt;
#   text-align: center;
# }
# #T_4f4c8_row3_col7 {
#   background-color: #21908d;
#   color: #f1f1f1;
#   font-size: 10pt;
#   text-align: center;
# }
# </style>
# <table id="T_4f4c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f4c8_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_4f4c8_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_4f4c8_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_4f4c8_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_4f4c8_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_4f4c8_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_4f4c8_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_4f4c8_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f4c8_level0_row0" class="row_heading level0 row0" >culmen_length_mm</th>
#       <td id="T_4f4c8_row0_col0" class="data row0 col0" >342.000000</td>
#       <td id="T_4f4c8_row0_col1" class="data row0 col1" >43.921930</td>
#       <td id="T_4f4c8_row0_col2" class="data row0 col2" >5.459584</td>
#       <td id="T_4f4c8_row0_col3" class="data row0 col3" >32.100000</td>
#       <td id="T_4f4c8_row0_col4" class="data row0 col4" >39.225000</td>
#       <td id="T_4f4c8_row0_col5" class="data row0 col5" >44.450000</td>
#       <td id="T_4f4c8_row0_col6" class="data row0 col6" >48.500000</td>
#       <td id="T_4f4c8_row0_col7" class="data row0 col7" >59.600000</td>
#     </tr>
#     <tr>
#       <th id="T_4f4c8_level0_row1" class="row_heading level0 row1" >culmen_depth_mm</th>
#       <td id="T_4f4c8_row1_col0" class="data row1 col0" >342.000000</td>
#       <td id="T_4f4c8_row1_col1" class="data row1 col1" >17.151170</td>
#       <td id="T_4f4c8_row1_col2" class="data row1 col2" >1.974793</td>
#       <td id="T_4f4c8_row1_col3" class="data row1 col3" >13.100000</td>
#       <td id="T_4f4c8_row1_col4" class="data row1 col4" >15.600000</td>
#       <td id="T_4f4c8_row1_col5" class="data row1 col5" >17.300000</td>
#       <td id="T_4f4c8_row1_col6" class="data row1 col6" >18.700000</td>
#       <td id="T_4f4c8_row1_col7" class="data row1 col7" >21.500000</td>
#     </tr>
#     <tr>
#       <th id="T_4f4c8_level0_row2" class="row_heading level0 row2" >flipper_length_mm</th>
#       <td id="T_4f4c8_row2_col0" class="data row2 col0" >342.000000</td>
#       <td id="T_4f4c8_row2_col1" class="data row2 col1" >200.915205</td>
#       <td id="T_4f4c8_row2_col2" class="data row2 col2" >14.061714</td>
#       <td id="T_4f4c8_row2_col3" class="data row2 col3" >172.000000</td>
#       <td id="T_4f4c8_row2_col4" class="data row2 col4" >190.000000</td>
#       <td id="T_4f4c8_row2_col5" class="data row2 col5" >197.000000</td>
#       <td id="T_4f4c8_row2_col6" class="data row2 col6" >213.000000</td>
#       <td id="T_4f4c8_row2_col7" class="data row2 col7" >231.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4f4c8_level0_row3" class="row_heading level0 row3" >body_mass_g</th>
#       <td id="T_4f4c8_row3_col0" class="data row3 col0" >342.000000</td>
#       <td id="T_4f4c8_row3_col1" class="data row3 col1" >4201.754386</td>
#       <td id="T_4f4c8_row3_col2" class="data row3 col2" >801.954536</td>
#       <td id="T_4f4c8_row3_col3" class="data row3 col3" >2700.000000</td>
#       <td id="T_4f4c8_row3_col4" class="data row3 col4" >3550.000000</td>
#       <td id="T_4f4c8_row3_col5" class="data row3 col5" >4050.000000</td>
#       <td id="T_4f4c8_row3_col6" class="data row3 col6" >4750.000000</td>
#       <td id="T_4f4c8_row3_col7" class="data row3 col7" >6300.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a id="checking-missing"></a>
# **Task 5 - Checking for Missing values and dealing with them**

# %%
data.isnull()
# Out:
#      species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0      False   False             False            False              False
# 1      False   False             False            False              False
# 2      False   False             False            False              False
# 3      False   False              True             True               True
# 4      False   False             False            False              False
# ..       ...     ...               ...              ...                ...
# 339    False   False              True             True               True
# 340    False   False             False            False              False
# 341    False   False             False            False              False
# 342    False   False             False            False              False
# 343    False   False             False            False              False
#
#      body_mass_g    sex
# 0          False  False
# 1          False  False
# 2          False  False
# 3           True   True
# 4          False  False
# ..           ...    ...
# 339         True   True
# 340        False  False
# 341        False  False
# 342        False  False
# 343        False  False
#
# [344 rows x 7 columns]

# %%
data.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
data.fillna(data.mean(), inplace=True)

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %% [markdown]
# <a id="finding-outliers"></a>
# **Task 6 - Finding the outliers and replacing them**

# %%
data
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 4         3450.0  FEMALE
# 5         3650.0    MALE
# ..           ...     ...
# 338       4925.0  FEMALE
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [334 rows x 7 columns]

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1

def replace_outliers(column):
    lower_bound = Q1[column] - 1.5 * IQR[column]
    upper_bound = Q3[column] + 1.5 * IQR[column]
    data[column] = np.where((data[column] < lower_bound) | (data[column] > upper_bound), data[column].median(), data[column])

columns_with_outliers = ['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm', 'body_mass_g']
for column in columns_with_outliers:
    replace_outliers(column)

# %% [markdown]
# <a id="checking-correlation"></a>
# **Task 7 - Checking the correlation of independent variables with the target**

# %%
correlation = data.corr()
target_correlation = correlation['body_mass_g']
target_correlation
# Out:
# culmen_length_mm     0.589066
# culmen_depth_mm     -0.472987
# flipper_length_mm    0.873211
# body_mass_g          1.000000
# Name: body_mass_g, dtype: float64

# %%
covariance = data.cov()
covariance
# Out:
#                    culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# culmen_length_mm          29.817295        -2.456922          49.932218
# culmen_depth_mm           -2.456922         3.872668         -15.969677
# flipper_length_mm         49.932218       -15.969677         196.621397
# body_mass_g             2588.842967      -749.137985        9854.668816
#
#                      body_mass_g
# culmen_length_mm     2588.842967
# culmen_depth_mm      -749.137985
# flipper_length_mm    9854.668816
# body_mass_g        647761.194952

# %% [markdown]
# <a id="checking-categorical"></a>
# **Task 8 - Checking for categorical columns and performing encoding**

# %%
le = LabelEncoder()

categorical_columns = ['species', 'island', 'sex']
for column in categorical_columns:
    data[column] = le.fit_transform(data[column])

# %%
data
# Out:
#      species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0          0       2              39.1             18.7              181.0
# 1          0       2              39.5             17.4              186.0
# 2          0       2              40.3             18.0              195.0
# 4          0       2              36.7             19.3              193.0
# 5          0       2              39.3             20.6              190.0
# ..       ...     ...               ...              ...                ...
# 338        2       0              47.2             13.7              214.0
# 340        2       0              46.8             14.3              215.0
# 341        2       0              50.4             15.7              222.0
# 342        2       0              45.2             14.8              212.0
# 343        2       0              49.9             16.1              213.0
#
#      body_mass_g  sex
# 0         3750.0    2
# 1         3800.0    1
# 2         3250.0    1
# 4         3450.0    1
# 5         3650.0    2
# ..           ...  ...
# 338       4925.0    1
# 340       4850.0    1
# 341       5750.0    2
# 342       5200.0    1
# 343       5400.0    2
#
# [334 rows x 7 columns]

# %% [markdown]
# <a id="splitting-dependent"></a>
# **Task 9 - Splitting the data into dependent and independent variables**

# %%
X = data.drop('species', axis=1)  # Independent variables
y = data['species']  # Dependent variable

# %% [markdown]
# <a id="scaling"></a>
# **Task 10 - Scaling the data**

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# <a id="splitting"></a>
# **Task 11 - Splitting the data into training and testing**

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# <a id="checking-shape"></a>
# **Task 12 - Checking the training and testing data shape**

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (267, 6)
# y_train shape: (267,)
# X_test shape: (67, 6)
# y_test shape: (67,)
